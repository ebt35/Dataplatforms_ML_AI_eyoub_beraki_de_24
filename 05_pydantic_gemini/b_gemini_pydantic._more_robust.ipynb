# %% [markdown]
# # Structure gemini outputs in a robust way

# %%
from google import genai


client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients
    """
)
print(response.text)
# Out:
# Get ready to slurp your way through some incredible flavors! Here are a few beloved Asian soup recipes, complete with a yummy description and their key ingredients:
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **Yummy Description:** Imagine a bowl of pure comfort – a deeply aromatic and savory beef broth, simmered for hours with fragrant spices like star anise, cinnamon, and cloves. It's served piping hot over delicate rice noodles, generously topped with tender slices of rare beef (cooked by the broth's heat!), fresh herbs like cilantro and basil, crunchy bean sprouts, and a squeeze of lime. Each spoonful is a harmonious blend of savory, sweet, salty, and herbaceous notes, making it utterly soul-satisfying.
#
# **Key Ingredients:**
# *   **For the Broth:** Beef bones (knuckles, oxtail), flank steak, onion, ginger, star anise, cinnamon stick, black cardamom, cloves, coriander seeds, rock sugar, fish sauce, salt.
# *   **Noodles:** Flat rice noodles (Bánh Phở).
# *   **Toppings:** Thinly sliced raw beef (e.g., eye of round, sirloin), cooked brisket or flank, beef meatballs (optional).
# *   **Garnishes:** Bean sprouts, fresh basil leaves, cilantro, sliced green onions, lime wedges, sliced jalapeños or bird's eye chilies, hoisin sauce, Sriracha.
#
# ---
#
# ### 2. Thai Tom Yum Goong (Hot and Sour Shrimp Soup)
#
# **Yummy Description:** Prepare for a vibrant explosion of flavors! This iconic Thai soup is a thrilling dance of spicy, sour, salty, and savory, with an incredible fragrance. A clear broth is infused with the unmistakable aromas of lemongrass, galangal, and kaffir lime leaves, brought to life with juicy shrimp and earthy mushrooms. A kick of chili and a tang of lime juice complete this exhilarating, palate-awakening experience that's both invigorating and utterly delicious.
#
# **Key Ingredients:**
# *   **Broth Base:** Chicken or vegetable stock.
# *   **Aromatics:** Lemongrass (bruised), galangal (sliced), kaffir lime leaves (torn).
# *   **Flavorings:** Fish sauce, lime juice, bird's eye chilies (fresh or paste), chili paste (Nam Prik Pao - optional for depth and color), sugar.
# *   **Protein:** Fresh shrimp (peeled and deveined).
# *   **Vegetables:** Straw mushrooms or oyster mushrooms, cherry tomatoes (halved).
# *   **Garnish:** Fresh cilantro leaves.
#
# ---
#
# ### 3. Japanese Miso Soup
#
# **Yummy Description:** This deceptively simple soup is a cornerstone of Japanese cuisine – a warm, comforting hug in a bowl. It features a light, savory dashi broth (seaweed and bonito flakes) infused with the rich, umami depth of fermented miso paste. Soft cubes of silken tofu, delicate strands of rehydrated wakame seaweed, and thinly sliced green onions complete this nourishing and incredibly satisfying soup that can be enjoyed any time of day.
#
# **Key Ingredients:**
# *   **Dashi Stock:** Water, kombu (dried kelp), bonito flakes (katsuobushi).
# *   **Miso Paste:** White miso (Shiro Miso) or red miso (Aka Miso), depending on desired strength.
# *   **Add-ins:** Silken tofu (cubed), dried wakame seaweed, green onions (sliced).
#
# ---
#
# ### 4. Chinese Hot and Sour Soup
#
# **Yummy Description:** A classic for a reason! This hearty and satisfying soup tantalizes your taste buds with a perfect balance of savory, spicy, and tangy flavors, all bound together in a wonderfully silky, thick broth. Shredded pork, bamboo shoots, wood ear mushrooms, and soft tofu swim in a broth that's seasoned with vinegar, white pepper, and a touch of soy, often finished with delicate egg ribbons. It's warming, complex, and incredibly addictive!
#
# **Key Ingredients:**
# *   **Broth Base:** Chicken or vegetable stock.
# *   **Flavorings:** Rice vinegar, soy sauce, white pepper, sesame oil, chili oil (optional).
# *   **Protein:** Shredded pork (or chicken), firm tofu (shredded).
# *   **Vegetables:** Dried wood ear mushrooms (rehydrated and sliced), bamboo shoots (shredded).
# *   **Thickener:** Cornstarch slurry.
# *   **Egg:** Whisked egg (poured slowly to create ribbons).
# *   **Garnish:** Green onions (sliced).
#
# ---
#
# ### 5. Malaysian/Singaporean Laksa (Curry Noodle Soup)
#
# **Yummy Description:** Get ready for a sensory feast! Laksa is a rich, creamy, and gloriously spicy coconut curry noodle soup that's utterly intoxicating. A complex broth, bursting with the flavors of lemongrass, galangal, turmeric, and dried chilies, is softened by luscious coconut milk. It's generously filled with a medley of thick rice vermicelli and/or egg noodles, juicy shrimp, shredded chicken, fish cakes, and tofu puffs, creating a truly decadent and unforgettable meal.
#
# **Key Ingredients:**
# *   **Broth Base:** Chicken or seafood broth, coconut milk, laksa paste (or individual spices: dried chilies, shallots, garlic, galangal, lemongrass, turmeric, candlenuts, belacan/shrimp paste).
# *   **Flavorings:** Fish sauce, sugar.
# *   **Noodles:** Thick rice vermicelli noodles, yellow egg noodles.
# *   **Protein:** Shrimp, shredded cooked chicken, fish cakes/balls, tofu puffs (tau pok).
# *   **Garnishes:** Bean sprouts, fresh mint leaves, cilantro, hard-boiled egg (halved), lime wedges, sambal (chili paste) for extra heat.
#
# ---
#
# Enjoy your culinary journey through Asia!

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients. Structure it in json format
    """
)
print(response.text)
# Out:
# ```json
# {
#   "asian_soups": [
#     {
#       "name": "Tom Yum Goong (Thai Spicy Shrimp Soup)",
#       "description": "A vibrant and exhilarating Thai classic, this hot and sour soup explodes with a complex symphony of flavors. Fragrant lemongrass, galangal, and kaffir lime leaves infuse a savory broth, perfectly balanced with the fiery kick of chilies, the tang of lime, and the umami depth of fish sauce, all enveloping succulent shrimp and earthy mushrooms. It's a truly intoxicating and aromatic culinary journey!",
#       "ingredients": [
#         "Shrimp (peeled and deveined)",
#         "Mushrooms (e.g., straw or oyster)",
#         "Lemongrass (bruised and sliced)",
#         "Galangal (sliced)",
#         "Kaffir lime leaves (torn)",
#         "Fish sauce",
#         "Lime juice",
#         "Chili paste (Nam Prik Pao)",
#         "Fresh chilies (sliced, optional)",
#         "Cilantro (for garnish)",
#         "Chicken or vegetable broth"
#       ]
#     },
#     {
#       "name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#       "description": "Experience the aromatic embrace of Vietnam's most beloved soup. A crystal-clear, deeply fragrant beef broth, simmered for hours with star anise, cinnamon, ginger, and cloves, cradles slippery rice noodles. Thinly sliced rare beef, fresh herbs like basil and cilantro, crunchy bean sprouts, and a squeeze of lime complete this incredibly comforting and deeply satisfying culinary masterpiece.",
#       "ingredients": [
#         "Beef bones (for broth)",
#         "Beef flank steak (or other cuts, thinly sliced)",
#         "Flat rice noodles",
#         "Onions",
#         "Ginger",
#         "Star anise",
#         "Cinnamon sticks",
#         "Cloves",
#         "Cardamom pods (optional)",
#         "Fish sauce",
#         "Sugar",
#         "Fresh basil",
#         "Mint",
#         "Cilantro",
#         "Lime wedges",
#         "Bean sprouts",
#         "Chilies (e.g., jalapeño or bird's eye)"
#       ]
#     },
#     {
#       "name": "Classic Japanese Ramen (Shoyu/Tonkotsu Inspired)",
#       "description": "Dive into a soul-warming bowl of Japanese ramen, where perfectly chewy noodles swim in a rich, deeply flavored broth – perhaps a savory shoyu (soy sauce-based) or a creamy, milky tonkotsu (pork bone-based). Topped with tender slices of chashu pork, a perfectly soft-boiled ajitama egg, crisp nori, and fresh scallions, each spoonful is a harmonious blend of textures and umami that utterly satisfies.",
#       "ingredients": [
#         "Ramen noodles",
#         "Pork belly (for chashu)",
#         "Eggs (for ajitama)",
#         "Nori seaweed sheets",
#         "Scallions (sliced)",
#         "Narutomaki (fish cake, optional)",
#         "Ramen broth (pork bone, chicken, or dashi based)",
#         "Soy sauce",
#         "Mirin",
#         "Sake (optional)",
#         "Miso paste (if making Miso Ramen)"
#       ]
#     },
#     {
#       "name": "Hot and Sour Soup (Sichuan Style)",
#       "description": "Brace yourself for a tantalizing dance of flavors in this iconic Chinese soup! A delightful interplay of tangy rice vinegar and fiery white pepper creates an invigorating kick, perfectly balanced by savory broth and umami mushrooms. Shredded pork, tofu, bamboo shoots, and whisked egg ribbons add a comforting texture to this truly addictive, palate-awakening bowl.",
#       "ingredients": [
#         "Pork loin (shredded)",
#         "Firm tofu (shredded or diced)",
#         "Dried wood ear mushrooms (rehydrated and sliced)",
#         "Dried shiitake mushrooms (rehydrated and sliced)",
#         "Bamboo shoots (shredded)",
#         "Eggs (whisked)",
#         "Chicken or vegetable broth",
#         "Rice vinegar",
#         "Soy sauce",
#         "White pepper",
#         "Sesame oil",
#         "Cornstarch (for thickening)",
#         "Green onions (for garnish)"
#       ]
#     }
#   ]
# }
# ```

# %%
from pydantic import BaseModel
from google import genai


class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]


client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients
    """,
    config={"response_mime_type": "application/json", "response_schema": list[Recipe]},
)

print(response.text)
# Out:
# [
#   {
#     "recipe_name": "Tom Yum Goong",
#     "description": "A classic Thai hot and sour soup, known for its vibrant flavors, aromatic herbs, and spicy kick. It's often made with shrimp and mushrooms, balancing tangy lime with savory fish sauce and fragrant lemongrass, creating an exhilarating culinary experience.",
#     "ingredients": [
#       "Shrimp",
#       "Lemongrass",
#       "Galangal",
#       "Kaffir lime leaves",
#       "Fish sauce",
#       "Lime juice",
#       "Chili paste",
#       "Mushrooms",
#       "Cherry tomatoes",
#       "Cilantro"
#     ]
#   },
#   {
#     "recipe_name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#     "description": "Vietnam's iconic beef noodle soup, Pho Bo, is celebrated for its incredibly fragrant and deeply flavorful broth, slow-cooked with warming spices. It's served with tender slices of beef, slippery rice noodles, and a generous plate of fresh herbs and sprouts, offering a harmonious blend of textures and tastes.",
#     "ingredients": [
#       "Beef broth",
#       "Rice noodles",
#       "Beef slices (e.g., brisket, rare steak)",
#       "Star anise",
#       "Cinnamon sticks",
#       "Cloves",
#       "Ginger",
#       "Onion",
#       "Fish sauce",
#       "Bean sprouts",
#       "Fresh basil",
#       "Cilantro",
#       "Lime wedges",
#       "Jalapeños"
#     ]
#   },
#   {
#     "recipe_name": "Ramen (Japanese Noodle Soup)",
#     "description": "A quintessential Japanese comfort food, ramen is a hearty noodle soup featuring a rich, umami-packed broth, chewy wheat noodles, and a delightful variety of toppings like tender chashu pork, a perfectly soft-boiled egg, crisp nori, and fresh scallions.",
#     "ingredients": [
#       "Ramen noodles",
#       "Pork or chicken broth (e.g., Tonkotsu, Shoyu)",
#       "Chashu pork",
#       "Soft-boiled egg",
#       "Nori (seaweed)",
#       "Scallions",
#       "Bamboo shoots",
#       "Mirin",
#       "Soy sauce"
#     ]
#   },
#   {
#     "recipe_name": "Wonton Soup (Chinese Dumpling Soup)",
#     "description": "A comforting and light Chinese soup featuring delicate, savory wontons filled with seasoned pork and shrimp, floating in a clear, aromatic chicken broth. It's often garnished with fresh scallions and a drizzle of sesame oil, making it a perfect appetizer or light meal.",
#     "ingredients": [
#       "Wontons (pork and shrimp filling)",
#       "Chicken broth",
#       "Soy sauce",
#       "Sesame oil",
#       "Scallions",
#       "Bok choy (optional)",
#       "White pepper"
#     ]
#   }
# ]

# %%
recipes = response.parsed
type(recipes), len(recipes)
# Out:
# (list, 4)

# %%
recipes[0]
# Out:
# Recipe(recipe_name='Tom Yum Goong', description="A classic Thai hot and sour soup, known for its vibrant flavors, aromatic herbs, and spicy kick. It's often made with shrimp and mushrooms, balancing tangy lime with savory fish sauce and fragrant lemongrass, creating an exhilarating culinary experience.", ingredients=['Shrimp', 'Lemongrass', 'Galangal', 'Kaffir lime leaves', 'Fish sauce', 'Lime juice', 'Chili paste', 'Mushrooms', 'Cherry tomatoes', 'Cilantro'])
